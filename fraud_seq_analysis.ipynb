# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("data/fraud_planner_v2.csv")
df.head()
# Out:
#                                             sequence  num_attempts       time  \
# 0                                                NaN            10  99.535624
# 1  {"sequence": ["action(govco, phishing, sally, ...             2  18.759920
# 2  {"sequence": ["action(james, phishing, grace, ...             1  10.905615
# 3  {"sequence": ["action(govco, impersonation, ol...             3  25.084986
# 4                                                NaN            10  90.514654
#
#    per_syntax_errors  per_semantic_errors  manual_check
# 0           1.000000                  0.0           NaN
# 1           0.500000                  0.0           0.0
# 2           0.000000                  0.0           0.5
# 3           0.666667                  0.0           1.0
# 4           0.100000                  0.9           NaN

# %%
# Filter successfully generated sequences
successful_df = df[df['sequence'].notna()]
successful_df.head()
# Out:
#                                             sequence  num_attempts       time  \
# 1  {"sequence": ["action(govco, phishing, sally, ...             2  18.759920
# 2  {"sequence": ["action(james, phishing, grace, ...             1  10.905615
# 3  {"sequence": ["action(govco, impersonation, ol...             3  25.084986
# 6  {"sequence": ["action(james, identity theft, o...             1   9.227755
# 9  {"sequence": ["action(govco, impersonation, sa...             3  19.853377
#
#    per_syntax_errors  per_semantic_errors  manual_check
# 1           0.500000             0.000000           0.0
# 2           0.000000             0.000000           0.5
# 3           0.666667             0.000000           1.0
# 6           0.000000             0.000000           0.0
# 9           0.333333             0.333333           1.0

# %%
len(successful_df)
# Out:
# 56

# %%
plt.hist(successful_df['num_attempts'])
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Distribution of Data")
plt.show()

# %%
plt.hist(successful_df['per_syntax_errors'])
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Distribution of Data")
plt.show()

# %%
bins = np.arange(0, 1.1, 0.1)

plt.hist(successful_df['per_semantic_errors'])
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Distribution of Data")
plt.show()

# %%
unsuccessful_df = df[df['sequence'].isna()]
unsuccessful_df.head()
# Out:
#   sequence  num_attempts        time  per_syntax_errors  per_semantic_errors  \
# 0      NaN            10   99.535624                1.0                  0.0
# 4      NaN            10   90.514654                0.1                  0.9
# 5      NaN            10   92.357309                1.0                  0.0
# 7      NaN            10  163.224439                0.2                  0.8
# 8      NaN            10  104.161205                1.0                  0.0
#
#    manual_check
# 0           NaN
# 4           NaN
# 5           NaN
# 7           NaN
# 8           NaN
